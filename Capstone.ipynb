# %% [markdown]
# <a href="https://colab.research.google.com/github/DivyeshAgarwaliitg21/Coding-Week-22-Opensource-Tasks/blob/main/Capstone.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import sklearn

# %%
df=pd.read_csv("train.csv")
df=df.rename(columns={'Offer %': 'offer'})
df.head(n=2)
# Out:
#       id                                              title  Rating maincateg  \
# 0  16695  Fashionable & Comfortable Bellies For Women  (...     3.9     Women
# 1   5120  Combo Pack of 4 Casual Shoes Sneakers For Men ...     3.8       Men
#
#    platform  price1  actprice1   offer  norating1  noreviews1  star_5f  \
# 0  Flipkart     698        999  30.13%       38.0         7.0     17.0
# 1  Flipkart     999       1999  50.03%      531.0        69.0    264.0
#
#    star_4f  star_3f  star_2f  star_1f  fulfilled1
# 0      9.0      6.0        3        3           0
# 1     92.0     73.0       29       73           1

# %%
df.columns
# Out:
# Index(['id', 'title', 'Rating', 'maincateg', 'platform', 'price1', 'actprice1',
#        'offer', 'norating1', 'noreviews1', 'star_5f', 'star_4f', 'star_3f',
#        'star_2f', 'star_1f', 'fulfilled1'],
#       dtype='object')

# %%
for i in df.columns:
  print(i,df[i].isna().sum())
# Out:
# id 0
# title 0
# rating 0
# maincateg 526
# platform 0
# price1 0
# actprice1 0
# offer 0
# norating1 678
# noreviews1 578
# 588
# 539
# 231
# id 0
# title 0
# Rating 0
# maincateg 526
# platform 0
# price1 0
# actprice1 0
# offer 0
# norating1 678
# noreviews1 578
# star_5f 588
# star_4f 539
# star_3f 231
# star_2f 0
# star_1f 0
# fulfilled1 0

# %%
df2=df.dropna(subset=['maincateg'])
df.fillna(subset=[''])

# %%
df2.head(n=42)
# Out:
#        id                                              title  Rating  \
# 0   16695  Fashionable & Comfortable Bellies For Women  (...     3.9
# 1    5120  Combo Pack of 4 Casual Shoes Sneakers For Men ...     3.8
# 2   18391         Cilia Mode Leo Sneakers For Women  (White)     4.4
# 3     495                            Men Black Sports Sandal     4.2
# 4   16408                            Men Green Sports Sandal     3.9
# 5    2692                            Women Pink Flats Sandal     4.1
# 6    3236                            Women Navy Heels Sandal     4.0
# 7   14633                           Women Blue Wedges Sandal     3.9
# 8    1872                         Sneakers For Women  (Pink)     4.2
# 9    1668                            Men Black, Beige Sandal     4.1
# 10  12634  TEMPO Men's Combo Pack of 3 Synthetic Loafers ...     3.3
# 11  19065                            Women Gold Heels Sandal     4.0
# 12  17455                                         Flip Flops     4.1
# ...
